# %% [markdown]
# w word 跳到下一个单词
# f fore 回到上一个单词       这两个非常常用
# 5 jkhl  向方向上移动数字格
# e end  到一个单词的末尾
# shift + 4 == 跳到本行末尾, 0 == 跳到本行开头  shift + 6 == 跳到本行首个非空字符
# ctrl + u == up向上翻页  ctrl + d == 向下翻页
# gg 回到文档开头  G 回到文档结尾
# f + 任意字母  f == find 向后在这行中跳转到对应字母处
# y 为复制    y ==yank(拉)  yaw           p为粘贴
# d 是删除, dd是删除一行, df + 字母表示删除到那个字母
# u == ctrl + z  撤销
# a == append 是在当前光标之后进行输入  i 之前    光标是包括当前的字符的!
# c == change 为改变      caw 改变当前词      cc 删除当前行, 并进入输入模式   c4j 删除下四行并进入输入模式
# v == vision 为可视模式
# gt 下一标签页, gT  上一标签页
# x  删除光标初的单字符

# %% [markdown]
# vscode的常用快捷键
# ctrl + ` 为   打开或隐藏终端
# ctrl + Tab  切换标签页(比vim的好用)
# ctrl + w    关闭标签页
# f10 逐行调试
# ctrl + /    快速注释
